# %%
import joblib
import numpy as np
import pandas as pd
import requests
from tqdm import tqdm

# %%
APP_ID = "3d0a5056c9a299b9f58bb53d62895c90"
USER_ID = 10915463

# %%
with open("autogluon_model.joblib", "rb") as f:
    model = joblib.load(f)

# %%
with open("means.joblib", "rb") as f:
    means = joblib.load(f)

# %%
with open("stds.joblib", "rb") as f:
    stds = joblib.load(f)

# %%
with open("columns.joblib", "rb") as f:
    final_columns = joblib.load(f)

# %%
url = f"https://papi.tanksblitz.ru/wotb/encyclopedia/vehicles/?application_id={APP_ID}"
response = requests.get(url)

# %%
general_data = []
general_columns = ["tank_id", "nation", "tier", "type", "name"]
premium_data = []
premium_columns = [
    "tank_id",
    "nation",
    "tier",
    "type",
    "name",
    "default_profile.firepower",
    "default_profile.hp",
    "default_profile.hull_hp",
    "default_profile.hull_weight",
    "default_profile.maneuverability",
    "default_profile.max_weight",
    "default_profile.protection",
    "default_profile.shot_efficiency",
    "default_profile.signal_range",
    "default_profile.speed_backward",
    "default_profile.speed_forward",
    "default_profile.weight",
    "default_profile.armor.hull.front",
    "default_profile.armor.hull.rear",
    "default_profile.armor.hull.sides",
    "default_profile.armor.turret.front",
    "default_profile.armor.turret.rear",
    "default_profile.armor.turret.sides",
    "default_profile.engine.fire_chance",
    "default_profile.engine.power",
    "default_profile.gun.aim_time",
    "default_profile.gun.caliber",
    "default_profile.gun.clip_capacity",
    "default_profile.gun.clip_reload_time",
    "default_profile.gun.dispersion",
    "default_profile.gun.fire_rate",
    "default_profile.gun.move_down_arc",
    "default_profile.gun.move_up_arc",
    "default_profile.gun.reload_time",
    "default_profile.gun.traverse_speed",
    "default_profile.suspension.load_limit",
    "default_profile.suspension.traverse_speed",
    "default_profile.turret.hp",
    "default_profile.turret.traverse_left_arc",
    "default_profile.turret.traverse_right_arc",
    "default_profile.turret.traverse_speed",
    "default_profile.turret.view_range",
]
for i in response.json().get("data").values():
    if i.get("is_premium"):
        temp_data = {}
        for col in premium_columns:
            temp = i
            splitted_col = col.split(".")
            for part_col in splitted_col:
                temp = temp.get(part_col)
            temp_data[col] = temp
        premium_data.append(temp_data)
    else:
        temp = {k: v for k, v in i.items() if k in general_columns}
        general_data.append(temp)

# %%
general_df = pd.DataFrame(general_data, columns=general_columns)
general_df
# Out:
#      tank_id    nation  tier        type                 name
# 0          1      ussr     5  mediumTank                 Т-34
# 1         17   germany     5  mediumTank  Pz.Kpfw. IV Ausf. G
# 2       1569       usa     7  mediumTank                  T20
# 3       8225       usa     8      AT-SPG                  T28
# 4       1297   germany     7  mediumTank            Panther I
# ..       ...       ...   ...         ...                  ...
# 235     3681     japan    10  mediumTank                STB-1
# 236     7505        uk     3  mediumTank       Cruiser Mk. IV
# 237     6273  european     7  mediumTank  Konštrukta T-34/100
# 238    20049        uk     8   lightTank                FV301
# 239     1841     china     9  mediumTank               WZ-120
#
# [240 rows x 5 columns]

# %%
premium_df = pd.DataFrame(premium_data, columns=premium_columns)
premium_df
# Out:
#      tank_id   nation  tier        type                    name  \
# 0       3073     ussr     3   lightTank                    Т-46
# 1       8049    other     5  mediumTank                     Шип
# 2      63841    japan     5  mediumTank     Panzer IV Lightning
# 3      52513      usa     7   heavyTank                  M6A2E1
# 4       6481       uk     4   lightTank              Covenanter
# ..       ...      ...   ...         ...                     ...
# 278     4977    other     5  mediumTank                 Мародёр
# 279    18753   france     8      AT-SPG  AMX Canon d'assaut 105
# 280    15889  germany     6  mediumTank            VK 30.02 (M)
# 281     4705    japan     6  mediumTank       Firefly Lightning
# 282     6001    other     7  mediumTank              Y5 ELC bis
#
#      default_profile.firepower  default_profile.hp  default_profile.hull_hp  \
# 0                           21                 480                      384
# 1                           30                 650                      496
# 2                           29                 710                      568
# 3                           47                1400                     1120
# 4                           29                 600                      480
# ..                         ...                 ...                      ...
# 278                         29                 700                      560
# 279                         61                1150                      920
# 280                         40                1050                      840
# 281                         44                 960                      768
# 282                         67                1300                     1060
#
#      default_profile.hull_weight  default_profile.maneuverability  ...  \
# 0                           7800                               72  ...
# 1                          12292                               47  ...
# 2                          11270                               48  ...
# 3                          36550                               30  ...
# 4                           9510                               50  ...
# ..                           ...                              ...  ...
# 278                        13145                               50  ...
# 279                        20175                               65  ...
# 280                        15950                               52  ...
# 281                        18110                               51  ...
# 282                        14900                               65  ...
#
#      default_profile.gun.move_up_arc  default_profile.gun.reload_time  \
# 0                                 16                             9.00
# 1                                 25                             7.80
# 2                                 20                             8.04
# 3                                 20                            10.50
# 4                                 20                            10.00
# ..                               ...                              ...
# 278                               12                             8.00
# 279                               20                             9.50
# 280                               18                             6.16
# 281                               20                             5.70
# 282                               13                             4.00
#
#      default_profile.gun.traverse_speed default_profile.suspension.load_limit  \
# 0                                 43.75                                 17300
# 1                                 35.00                                 25000
# 2                                 35.00                                 28000
# 3                                 35.00                                 70500
# 4                                 43.75                                 20500
# ..                                  ...                                   ...
# 278                               40.25                                 37000
# 279                               20.00                                 32000
# 280                               35.00                                 45000
# 281                               40.25                                 36100
# 282                               40.25                                 38000
#
#      default_profile.suspension.traverse_speed  default_profile.turret.hp  \
# 0                                           48                         96
# 1                                           33                        154
# 2                                           35                        142
# 3                                           25                        280
# 4                                           40                        120
# ..                                         ...                        ...
# 278                                         38                        140
# 279                                         37                        230
# 280                                         38                        210
# 281                                         42                        192
# 282                                         45                        240
#
#      default_profile.turret.traverse_left_arc  \
# 0                                         180
# 1                                         180
# 2                                         180
# 3                                         180
# 4                                         180
# ..                                        ...
# 278                                       180
# 279                                        10
# 280                                       180
# 281                                       180
# 282                                       180
#
#      default_profile.turret.traverse_right_arc  \
# 0                                          180
# 1                                          180
# 2                                          180
# 3                                          180
# 4                                          180
# ..                                         ...
# 278                                        180
# 279                                         10
# 280                                        180
# 281                                        180
# 282                                        180
#
#      default_profile.turret.traverse_speed  default_profile.turret.view_range
# 0                                       44                                220
# 1                                       40                                240
# 2                                       48                                240
# 3                                       25                                250
# 4                                       48                                230
# ..                                     ...                                ...
# 278                                     42                                240
# 279                                     26                                240
# 280                                     30                                240
# 281                                     39                                240
# 282                                     40                                250
#
# [283 rows x 42 columns]

# %%
tank_drop_ids = [21793, 64769, 64273, 64801]
premium_df = premium_df[~premium_df.tank_id.isin(tank_drop_ids)]

# %%
columns = ["user_id", "tank_id"]
user_tanks_columns = [
    "spotted",
    "hits",
    "frags",
    "max_xp",
    "wins",
    "losses",
    "capture_points",
    "battles",
    "damage_dealt",
    "damage_received",
    "max_frags",
    "shots",
    "frags8p",
    "xp",
    "win_and_survived",
    "survived_battles",
    "dropped_capture_points",
]
tanks_columns = ["battle_life_time", "mark_of_mastery"]
columns = columns + user_tanks_columns + tanks_columns

# %%
user_df = pd.DataFrame()
url = f"https://papi.tanksblitz.ru/wotb/tanks/stats/?application_id={APP_ID}&account_id={USER_ID}"
data = requests.get(url).json()
data = data.get("data").get(f"{USER_ID}")
if data != None:
    for el in data:
        full_data = {"user_id": [USER_ID]}
        full_data["tank_id"] = el.get("tank_id")
        full_data["battle_life_time"] = [el.get("battle_life_time")]
        full_data["mark_of_mastery"] = [el.get("mark_of_mastery")]
        for k, v in el.get("all").items():
            full_data[k] = [v]
        temp_df = pd.DataFrame(full_data, columns=columns)
        user_df = pd.concat([user_df, temp_df], ignore_index=True)

# %%
user_df
# Out:
#       user_id  tank_id  spotted  hits  frags  max_xp  wins  losses  \
# 0    10915463     6961        8   146     35    1689    15       7
# 1    10915463     8257        8   160     15     439     8      11
# 2    10915463      769       30   130     11     664     9       8
# 3    10915463     9073        0     0      0     499     0       0
# 4    10915463     2849       78   469     92    1825    46      36
# ..        ...      ...      ...   ...    ...     ...   ...     ...
# 283  10915463     4993        0     0      0       0     0       0
# 284  10915463     7745        6    46      5     629     2       0
# 285  10915463      801       65   410     50    1089    33      26
# 286  10915463      385      111   492     53    2007    29      30
# 287  10915463     6417       99   348     51    1561    34      28
#
#      capture_points  battles  ...  damage_received  max_frags  shots  frags8p  \
# 0                 0       22  ...            16336          4    167       27
# 1                 0       20  ...             4988          3    183        0
# 2                 0       17  ...             6627          2    138        0
# 3                 0        0  ...                0          0      0        0
# 4                 0       82  ...           113304          4    540       77
# ..              ...      ...  ...              ...        ...    ...      ...
# 283               0        0  ...                0          0      0        0
# 284               0        2  ...              256          3     59        0
# 285               0       59  ...            52265          4    481        0
# 286               0       60  ...            95780          4    572       53
# 287               0       63  ...            37967          6    402        0
#
#         xp  win_and_survived  survived_battles  dropped_capture_points  \
# 0    23985                12                12                      23
# 1     4305                 4                 4                       0
# 2     4216                 1                 1                       5
# 3        0                 0                 0                       0
# 4    71896                33                33                      24
# ..     ...               ...               ...                     ...
# 283      0                 0                 0                       0
# 284    980                 2                 2                       0
# 285  29673                17                17                      31
# 286  56951                22                22                      94
# 287  26627                14                14                      88
#
#      battle_life_time  mark_of_mastery
# 0                5954                2
# 1                2702                2
# 2                1653                2
# 3                 157                0
# 4               16757                3
# ..                ...              ...
# 283                 0                0
# 284               382                3
# 285              8896                3
# 286             11865                4
# 287              8390                4
#
# [288 rows x 21 columns]

# %%
user_general_df = user_df[user_df.tank_id.isin(general_df.tank_id.values)]
user_general_df = user_general_df.query(
    "(battles >= wins + losses) & (battles > 10) & (damage_dealt > 0)"
)
user_general_df
# Out:
#       user_id  tank_id  spotted  hits  frags  max_xp  wins  losses  \
# 2    10915463      769       30   130     11     664     9       8
# 9    10915463     6721       73   313     38    1018    32      22
# 10   10915463     3921      154  1274     90    1842    71      72
# 15   10915463     8785       23   496     44    1096    22      19
# 16   10915463     2321       49   416     52    1600    27      17
# ..        ...      ...      ...   ...    ...     ...   ...     ...
# 277  10915463     1809       18   259     50    1129    25      21
# 278  10915463     7185       73   451     53    1278    34      27
# 280  10915463    18433       34    67      8    1176     7       4
# 285  10915463      801       65   410     50    1089    33      26
# 286  10915463      385      111   492     53    2007    29      30
#
#      capture_points  battles  ...  damage_received  max_frags  shots  frags8p  \
# 2                 0       17  ...             6627          2    138        0
# 9               106       55  ...            34031          3    362        0
# 10               58      144  ...           201621          5   1435       63
# 15              111       41  ...            19262          4    587        0
# 16               48       44  ...            38085          5    482        0
# ..              ...      ...  ...              ...        ...    ...      ...
# 277              22       46  ...            15306          4    298        0
# 278               0       61  ...            44804          4    524        0
# 280               0       11  ...             8749          2     74        0
# 285               0       59  ...            52265          4    481        0
# 286               0       60  ...            95780          4    572       53
#
#         xp  win_and_survived  survived_battles  dropped_capture_points  \
# 2     4216                 1                 1                       5
# 9    25089                22                22                       9
# 10   85451                36                36                     122
# 15   17956                16                17                       3
# 16   31577                21                21                      35
# ..     ...               ...               ...                     ...
# 277  15589                16                16                       1
# 278  37868                20                20                       1
# 280   7977                 4                 4                       0
# 285  29673                17                17                      31
# 286  56951                22                22                      94
#
#      battle_life_time  mark_of_mastery
# 2                1653                2
# 9                7900                4
# 10              21803                3
# 15               7551                3
# 16               7294                4
# ..                ...              ...
# 277              7955                3
# 278              8822                2
# 280              1354                2
# 285              8896                3
# 286             11865                4
#
# [77 rows x 21 columns]

# %%
avg_cols = user_general_df.drop(
    ["user_id", "tank_id", "max_xp", "battles", "max_frags", "mark_of_mastery"], axis=1
).columns
user_general_df[avg_cols] = (
    user_general_df[avg_cols].div(user_general_df["battles"], axis=0).astype("float32")
)
user_general_df
# Out:
#       user_id  tank_id   spotted       hits     frags  max_xp      wins  \
# 2    10915463      769  1.764706   7.647059  0.647059     664  0.529412
# 9    10915463     6721  1.327273   5.690909  0.690909    1018  0.581818
# 10   10915463     3921  1.069444   8.847222  0.625000    1842  0.493056
# 15   10915463     8785  0.560976  12.097561  1.073171    1096  0.536585
# 16   10915463     2321  1.113636   9.454545  1.181818    1600  0.613636
# ..        ...      ...       ...        ...       ...     ...       ...
# 277  10915463     1809  0.391304   5.630435  1.086957    1129  0.543478
# 278  10915463     7185  1.196721   7.393443  0.868852    1278  0.557377
# 280  10915463    18433  3.090909   6.090909  0.727273    1176  0.636364
# 285  10915463      801  1.101695   6.949152  0.847458    1089  0.559322
# 286  10915463      385  1.850000   8.200000  0.883333    2007  0.483333
#
#        losses  capture_points  battles  ...  damage_received  max_frags  \
# 2    0.470588        0.000000       17  ...       389.823517          2
# 9    0.400000        1.927273       55  ...       618.745483          3
# 10   0.500000        0.402778      144  ...      1400.145874          5
# 15   0.463415        2.707317       41  ...       469.804871          4
# 16   0.386364        1.090909       44  ...       865.568176          5
# ..        ...             ...      ...  ...              ...        ...
# 277  0.456522        0.478261       46  ...       332.739136          4
# 278  0.442623        0.000000       61  ...       734.491821          4
# 280  0.363636        0.000000       11  ...       795.363647          2
# 285  0.440678        0.000000       59  ...       885.847473          4
# 286  0.500000        0.000000       60  ...      1596.333374          4
#
#          shots   frags8p          xp  win_and_survived  survived_battles  \
# 2     8.117647  0.000000  248.000000          0.058824          0.058824
# 9     6.581818  0.000000  456.163635          0.400000          0.400000
# 10    9.965278  0.437500  593.409729          0.250000          0.250000
# 15   14.317073  0.000000  437.951233          0.390244          0.414634
# 16   10.954545  0.000000  717.659119          0.477273          0.477273
# ..         ...       ...         ...               ...               ...
# 277   6.478261  0.000000  338.891296          0.347826          0.347826
# 278   8.590164  0.000000  620.786865          0.327869          0.327869
# 280   6.727273  0.000000  725.181824          0.363636          0.363636
# 285   8.152542  0.000000  502.932190          0.288136          0.288136
# 286   9.533334  0.883333  949.183350          0.366667          0.366667
#
#      dropped_capture_points  battle_life_time  mark_of_mastery
# 2                  0.294118         97.235291                2
# 9                  0.163636        143.636368                4
# 10                 0.847222        151.409729                3
# 15                 0.073171        184.170731                3
# 16                 0.795455        165.772720                4
# ..                      ...               ...              ...
# 277                0.021739        172.934784                3
# 278                0.016393        144.622955                2
# 280                0.000000        123.090912                2
# 285                0.525424        150.779663                3
# 286                1.566667        197.750000                4
#
# [77 rows x 21 columns]

# %%
already_has = user_df[user_df.tank_id.isin(premium_df.tank_id.values)].tank_id.values
predict_prem_df = premium_df[~premium_df.tank_id.isin(already_has)].query("tier >= 5")
predict_prem_df
# Out:
#      tank_id   nation  tier        type                    name  \
# 1       8049    other     5  mediumTank                     Шип
# 2      63841    japan     5  mediumTank     Panzer IV Lightning
# 3      52513      usa     7   heavyTank                  M6A2E1
# 6      63585    japan     6   heavyTank   Tiger Kuromorimine SP
# 13     21281      usa     6  mediumTank                 Рудольф
# ..       ...      ...   ...         ...                     ...
# 277      817    china     8   heavyTank                  WZ-111
# 279    18753   france     8      AT-SPG  AMX Canon d'assaut 105
# 280    15889  germany     6  mediumTank            VK 30.02 (M)
# 281     4705    japan     6  mediumTank       Firefly Lightning
# 282     6001    other     7  mediumTank              Y5 ELC bis
#
#      default_profile.firepower  default_profile.hp  default_profile.hull_hp  \
# 1                           30                 650                      496
# 2                           29                 710                      568
# 3                           47                1400                     1120
# 6                           48                1150                      920
# 13                          44                 980                      736
# ..                         ...                 ...                      ...
# 277                         45                1800                     1440
# 279                         61                1150                      920
# 280                         40                1050                      840
# 281                         44                 960                      768
# 282                         67                1300                     1060
#
#      default_profile.hull_weight  default_profile.maneuverability  ...  \
# 1                          12292                               47  ...
# 2                          11270                               48  ...
# 3                          36550                               30  ...
# 6                          25350                               30  ...
# 13                         19600                               52  ...
# ..                           ...                              ...  ...
# 277                        18845                               30  ...
# 279                        20175                               65  ...
# 280                        15950                               52  ...
# 281                        18110                               51  ...
# 282                        14900                               65  ...
#
#      default_profile.gun.move_up_arc  default_profile.gun.reload_time  \
# 1                                 25                             7.80
# 2                                 20                             8.04
# 3                                 20                            10.50
# 6                                 17                             7.30
# 13                                25                             5.70
# ..                               ...                              ...
# 277                               23                            14.00
# 279                               20                             9.50
# 280                               18                             6.16
# 281                               20                             5.70
# 282                               13                             4.00
#
#      default_profile.gun.traverse_speed default_profile.suspension.load_limit  \
# 1                                 35.00                                 25000
# 2                                 35.00                                 28000
# 3                                 35.00                                 70500
# 6                                 35.00                                 61000
# 13                                40.25                                 38500
# ..                                  ...                                   ...
# 277                               26.25                                 48000
# 279                               20.00                                 32000
# 280                               35.00                                 45000
# 281                               40.25                                 36100
# 282                               40.25                                 38000
#
#      default_profile.suspension.traverse_speed  default_profile.turret.hp  \
# 1                                           33                        154
# 2                                           35                        142
# 3                                           25                        280
# 6                                           27                        230
# 13                                          44                        244
# ..                                         ...                        ...
# 277                                         30                        360
# 279                                         37                        230
# 280                                         38                        210
# 281                                         42                        192
# 282                                         45                        240
#
#      default_profile.turret.traverse_left_arc  \
# 1                                         180
# 2                                         180
# 3                                         180
# 6                                         180
# 13                                        180
# ..                                        ...
# 277                                       180
# 279                                        10
# 280                                       180
# 281                                       180
# 282                                       180
#
#      default_profile.turret.traverse_right_arc  \
# 1                                          180
# 2                                          180
# 3                                          180
# 6                                          180
# 13                                         180
# ..                                         ...
# 277                                        180
# 279                                         10
# 280                                        180
# 281                                        180
# 282                                        180
#
#      default_profile.turret.traverse_speed  default_profile.turret.view_range
# 1                                       40                                240
# 2                                       48                                240
# 3                                       25                                250
# 6                                       20                                240
# 13                                      39                                240
# ..                                     ...                                ...
# 277                                     26                                240
# 279                                     26                                240
# 280                                     30                                240
# 281                                     39                                240
# 282                                     40                                250
#
# [113 rows x 42 columns]

# %%
predict_prem_df = predict_prem_df.drop(["name", "default_profile.signal_range"], axis=1)

# %%
user_general_df = user_general_df.pivot(index="user_id", columns="tank_id")
user_general_df.columns = [
    "_".join([str(part) for part in col if part not in (None, "")])
    for col in user_general_df.columns
]
user_general_df.reset_index(inplace=True)
user_general_df
# Out:
#     user_id  spotted_1  spotted_17  spotted_257  spotted_385  spotted_529  \
# 0  10915463   1.322581    1.377049     0.977273         1.85          1.2
#
#    spotted_769  spotted_801  spotted_849  spotted_1025  ...  \
# 0     1.764706     1.101695     0.852941      1.916667  ...
#
#    mark_of_mastery_11793  mark_of_mastery_13841  mark_of_mastery_14097  \
# 0                      3                      3                      3
#
#    mark_of_mastery_14145  mark_of_mastery_14865  mark_of_mastery_15649  \
# 0                      3                      3                      4
#
#    mark_of_mastery_16641  mark_of_mastery_18001  mark_of_mastery_18433  \
# 0                      3                      3                      2
#
#    mark_of_mastery_58641
# 0                      4
#
# [1 rows x 1464 columns]

# %%
prem_cols = (
    ["tank_id"]
    + [col for col in predict_prem_df.columns if "default_profile" in col]
    + ["nation", "tier", "type"]
)
predict_prem_df = predict_prem_df[prem_cols]
predict_prem_df
# Out:
#      tank_id  default_profile.firepower  default_profile.hp  \
# 1       8049                         30                 650
# 2      63841                         29                 710
# 3      52513                         47                1400
# 6      63585                         48                1150
# 13     21281                         44                 980
# ..       ...                        ...                 ...
# 277      817                         45                1800
# 279    18753                         61                1150
# 280    15889                         40                1050
# 281     4705                         44                 960
# 282     6001                         67                1300
#
#      default_profile.hull_hp  default_profile.hull_weight  \
# 1                        496                        12292
# 2                        568                        11270
# 3                       1120                        36550
# 6                        920                        25350
# 13                       736                        19600
# ..                       ...                          ...
# 277                     1440                        18845
# 279                      920                        20175
# 280                      840                        15950
# 281                      768                        18110
# 282                     1060                        14900
#
#      default_profile.maneuverability  default_profile.max_weight  \
# 1                                 47                       25000
# 2                                 48                       28000
# 3                                 30                       70500
# 6                                 30                       61000
# 13                                52                       38500
# ..                               ...                         ...
# 277                               30                       48000
# 279                               65                       32000
# 280                               52                       45000
# 281                               51                       36100
# 282                               65                       38000
#
#      default_profile.protection  default_profile.shot_efficiency  \
# 1                             0                               45
# 2                             0                               43
# 3                             0                               58
# 6                             0                               51
# 13                            0                               51
# ..                          ...                              ...
# 277                           0                               64
# 279                           0                               83
# 280                           0                               59
# 281                           0                               65
# 282                           0                               61
#
#      default_profile.speed_backward  ...  \
# 1                                20  ...
# 2                                18  ...
# 3                                10  ...
# 6                                12  ...
# 13                               20  ...
# ..                              ...  ...
# 277                              17  ...
# 279                              20  ...
# 280                              20  ...
# 281                              18  ...
# 282                              23  ...
#
#      default_profile.suspension.load_limit  \
# 1                                    25000
# 2                                    28000
# 3                                    70500
# 6                                    61000
# 13                                   38500
# ..                                     ...
# 277                                  48000
# 279                                  32000
# 280                                  45000
# 281                                  36100
# 282                                  38000
#
#      default_profile.suspension.traverse_speed  default_profile.turret.hp  \
# 1                                           33                        154
# 2                                           35                        142
# 3                                           25                        280
# 6                                           27                        230
# 13                                          44                        244
# ..                                         ...                        ...
# 277                                         30                        360
# 279                                         37                        230
# 280                                         38                        210
# 281                                         42                        192
# 282                                         45                        240
#
#      default_profile.turret.traverse_left_arc  \
# 1                                         180
# 2                                         180
# 3                                         180
# 6                                         180
# 13                                        180
# ..                                        ...
# 277                                       180
# 279                                        10
# 280                                       180
# 281                                       180
# 282                                       180
#
#      default_profile.turret.traverse_right_arc  \
# 1                                          180
# 2                                          180
# 3                                          180
# 6                                          180
# 13                                         180
# ..                                         ...
# 277                                        180
# 279                                         10
# 280                                        180
# 281                                        180
# 282                                        180
#
#      default_profile.turret.traverse_speed  default_profile.turret.view_range  \
# 1                                       40                                240
# 2                                       48                                240
# 3                                       25                                250
# 6                                       20                                240
# 13                                      39                                240
# ..                                     ...                                ...
# 277                                     26                                240
# 279                                     26                                240
# 280                                     30                                240
# 281                                     39                                240
# 282                                     40                                250
#
#       nation  tier        type
# 1      other     5  mediumTank
# 2      japan     5  mediumTank
# 3        usa     7   heavyTank
# 6      japan     6   heavyTank
# 13       usa     6  mediumTank
# ..       ...   ...         ...
# 277    china     8   heavyTank
# 279   france     8      AT-SPG
# 280  germany     6  mediumTank
# 281    japan     6  mediumTank
# 282    other     7  mediumTank
#
# [113 rows x 40 columns]

# %%
X = user_general_df.merge(predict_prem_df, how="cross")

# %%
needed_columns = list(set(final_columns).difference(set(X.columns)))

# %%
X = pd.concat([X, pd.DataFrame(columns=needed_columns)], axis=1)

# %%
X = X[["user_id", "tank_id"] + list(final_columns)]

# %%
def scale_data(data, means, stds):
    X_values = data.to_numpy(dtype=np.float32)
    X_values = (X_values - means) / stds

    return X_values

# %%
cat_cols = [col for col in X.columns if "mark_of_mastery" in col] + [
    "nation",
    "tier",
    "type",
]
num_cols = [col for col in X.columns if col not in ["user_id", "tank_id"] + cat_cols]

# %%
X[num_cols] = scale_data(X[num_cols], means, stds)

# %%
X[cat_cols] = X[cat_cols].astype("category")

# %%
X["preds"] = model.predict(X[final_columns]).round().astype(int)

# %%
res = X[["tank_id", "preds"]].sort_values("preds", ascending=False).head(3)
